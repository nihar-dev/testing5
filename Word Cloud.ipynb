# %%
brief = """
Abhishek is part of the WCAO Global Team under the Accounts VS.
It’s a very complex project with the vision to re-invent the account opening journey across geographies.
There is Global component and then there are local requirements with regards to the Account Opening.
This team manages the pre-discovery and discovery phase to understand the gaps between the global needs vs the local needs. 
Currently engaged with the UK Market where he is playing a role of a PM for WCAO UK discovery, 
co-ordinating with UK market Business Team Project Manager. 
Scheduled and successfully organised the Workshop with WCAO global and UK market stakeholders and all other key contributors. 
The workshop was conducted successfully and received appreciation email from the WCAO global Director.
Prepared the action log as a key outcome of the workshop and following it up with UK business team Project manager for 
the closure. As a BA, he is working closely with UK market BAs and other WCAO BAs to do the gap analysis for
WCAO product and the UK market business.
 """

possitive = """Very professional, excellent domain expertise in account opening,
understands the problems and very quick to pick up the conversations and the requirements to put into the actions required"""

Ebis = """As this was his first engagement, there was a learning curve and he coped up well with the demands,
works well with colleagues and other stakeholders.
I would like for him to focus on the learnings from the overall project aspect with the UK journey so that he is able to lead the next market's Discovery phase on his own. He has the knowledge, 
the domain expertise to become a Prodcut Owner for Accout Opening
in the future and we would like him to work towards that goal in the future."""

# %%
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS

stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(brief)
rcParams['figure.figsize'] = 10, 20
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in brief.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
    print(letter,count)
print(words,counts)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000022039AAA400>
# UK 7
# WCAO 6
# market 4
# global 3
# Global 2
# Team 2
# local 2
# team 2
# Project 2
# successfully 2
# ['UK', 'WCAO', 'market', 'global', 'Global', 'Team', 'local', 'team', 'Project', 'successfully'] [7, 6, 4, 3, 2, 2, 2, 2, 2, 2]

# %%
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(possitive)
rcParams['figure.figsize'] = 10, 20
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in possitive.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
print(words,filtered_words)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
# ['Very', 'professional,', 'excellent', 'domain', 'expertise', 'account', 'opening,', 'understands', 'problems', 'quick'] ['Very', 'professional,', 'excellent', 'domain', 'expertise', 'account', 'opening,', 'understands', 'problems', 'quick', 'pick', 'conversations', 'requirements', 'put', 'actions', 'required']

# %%
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(Ebis)
rcParams['figure.figsize'] = 10, 20
print(wordcloud.to_html)

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in Ebis.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)

words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
print(words,filtered_words)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
# <bound method WordCloud.to_html of <wordcloud.wordcloud.WordCloud object at 0x000002203AEB52B0>>
# ['well', 'As', 'first', 'engagement,', 'learning', 'curve', 'coped', 'demands,', 'works', 'colleagues'] ['As', 'first', 'engagement,', 'learning', 'curve', 'coped', 'well', 'demands,', 'works', 'well', 'colleagues', 'stakeholders.', 'I', 'focus', 'learnings', 'overall', 'project', 'aspect', 'UK', 'journey', 'able', 'lead', 'next', "market's", 'Discovery', 'phase', 'own.', 'He', 'knowledge,', 'domain', 'expertise', 'become', 'Prodcut', 'Owner', 'Accout', 'Opening', 'future', 'work', 'towards', 'goal', 'future.']
